# %%
# !git clone https://github.com/ultralytics/yolov5.git
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 15274, done.
# remote: Counting objects: 100% (38/38), done.
# remote: Compressing objects: 100% (33/33), done.
# remote: Total 15274 (delta 11), reused 23 (delta 5), pack-reused 15236
# Receiving objects: 100% (15274/15274), 14.17 MiB | 20.73 MiB/s, done.
# Resolving deltas: 100% (10467/10467), done.

# %%
# %cd yolov5/
# Out:
# /content/yolov5

# %%
# !pip install -U -r requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting gitpython>=3.1.30
#   Downloading GitPython-3.1.31-py3-none-any.whl (184 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.3/184.3 KB 4.8 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib>=3.2.2 in /usr/local/lib/python3.8/dist-packages (from -r requirements.txt (line 6)) (3.5.3)
# Collecting matplotlib>=3.2.2
#   Downloading matplotlib-3.7.0-cp38-cp38-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (9.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.2/9.2 MB 41.8 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.8/dist-packages (from -r requirements.txt (line 7)) (1.22.4)
# Collecting numpy>=1.18.5
#   Downloading numpy-1.24.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 74.1 MB/s eta 0:00:00
# Requirement already satisfied: opencv-python>=4.1.1 in /usr/local/lib/python3.8/dist-packages (from -r requirements.txt (line 8)) (4.6.0.66)
# Collecting opencv-python>=4.1.1
#   Downloading opencv_python-4.7.0.72-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (61.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.8/61.8 MB 13.5 MB/s eta 0:00:00
# Requirement already satisfied: Pillow>=7.1.2 in /usr/local/lib/python3.8/dist-packages (from -r requirements.txt (line 9)) (7.1.2)
# Collecting Pillow>=7.1.2
#   Downloading Pillow-9.4.0-cp38-cp38-manylinux_2_28_x86_64.whl (3.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 82.0 MB/s eta 0:00:00
# Requirement already satisfied: psutil in /usr/local/lib/python3.8/dist-packages (from -r requirements.txt (line 10)) (5.4.8)
# Collecting psutil
#   Downloading psutil-5.9.4-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (280 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 280.2/280.2 KB 7.8 MB/s eta 0:00:00
# Requirement already satisfied: PyYAML>=5.3.1 in /usr/local/lib/python3.8/dist-packages (from -r requirements.txt (line 11)) (6.0)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.8/dist-packages (from -r requirements.txt (line 12)) (2.25.1)
# Collecting requests>=2.23.0
#   Downloading requests-2.28.2-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 KB 5.9 MB/s eta 0:00:00
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.8/dist-packages (from -r requirements.txt (line 13)) (1.7.3)
# Collecting scipy>=1.4.1
#   Downloading scipy-1.10.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (34.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.5/34.5 MB 30.7 MB/s eta 0:00:00
# Collecting thop>=0.1.1
#   Downloading thop-0.1.1.post2209072238-py3-none-any.whl (15 kB)
# Requirement already satisfied: torch>=1.7.0 in /usr/local/lib/python3.8/dist-packages (from -r requirements.txt (line 15)) (1.13.1+cu116)
# Requirement already satisfied: torchvision>=0.8.1 in /usr/local/lib/python3.8/dist-packages (from -r requirements.txt (line 16)) (0.14.1+cu116)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.8/dist-packages (from -r requirements.txt (line 17)) (4.64.1)
# Requirement already satisfied: tensorboard>=2.4.1 in /usr/local/lib/python3.8/dist-packages (from -r requirements.txt (line 21)) (2.11.2)
# Collecting tensorboard>=2.4.1
#   Downloading tensorboard-2.12.0-py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 59.4 MB/s eta 0:00:00
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.8/dist-packages (from -r requirements.txt (line 26)) (1.3.5)
# Collecting pandas>=1.1.4
#   Downloading pandas-1.5.3-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.2/12.2 MB 90.2 MB/s eta 0:00:00
# Requirement already satisfied: seaborn>=0.11.0 in /usr/local/lib/python3.8/dist-packages (from -r requirements.txt (line 27)) (0.11.2)
# Collecting seaborn>=0.11.0
#   Downloading seaborn-0.12.2-py3-none-any.whl (293 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 293.3/293.3 KB 29.5 MB/s eta 0:00:00
# Collecting setuptools>=65.5.1
#   Downloading setuptools-67.4.0-py3-none-any.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 63.5 MB/s eta 0:00:00
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.10-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 KB 7.1 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=3.2.2->-r requirements.txt (line 6)) (2.8.2)
# Collecting contourpy>=1.0.1
#   Downloading contourpy-1.0.7-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (300 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 300.0/300.0 KB 30.9 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=3.2.2->-r requirements.txt (line 6)) (23.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=3.2.2->-r requirements.txt (line 6)) (3.0.9)
# Requirement already satisfied: importlib-resources>=3.2.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=3.2.2->-r requirements.txt (line 6)) (5.12.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=3.2.2->-r requirements.txt (line 6)) (4.38.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=3.2.2->-r requirements.txt (line 6)) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=3.2.2->-r requirements.txt (line 6)) (0.11.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests>=2.23.0->-r requirements.txt (line 12)) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests>=2.23.0->-r requirements.txt (line 12)) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests>=2.23.0->-r requirements.txt (line 12)) (2022.12.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.8/dist-packages (from requests>=2.23.0->-r requirements.txt (line 12)) (3.0.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.8/dist-packages (from torch>=1.7.0->-r requirements.txt (line 15)) (4.5.0)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.8/dist-packages (from tensorboard>=2.4.1->-r requirements.txt (line 21)) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.8/dist-packages (from tensorboard>=2.4.1->-r requirements.txt (line 21)) (1.51.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard>=2.4.1->-r requirements.txt (line 21)) (1.8.1)
# Requirement already satisfied: protobuf>=3.19.6 in /usr/local/lib/python3.8/dist-packages (from tensorboard>=2.4.1->-r requirements.txt (line 21)) (3.19.6)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.8/dist-packages (from tensorboard>=2.4.1->-r requirements.txt (line 21)) (2.16.1)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.8/dist-packages (from tensorboard>=2.4.1->-r requirements.txt (line 21)) (0.38.4)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from tensorboard>=2.4.1->-r requirements.txt (line 21)) (1.0.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.8/dist-packages (from tensorboard>=2.4.1->-r requirements.txt (line 21)) (3.4.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.8/dist-packages (from tensorboard>=2.4.1->-r requirements.txt (line 21)) (0.4.6)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0
#   Downloading tensorboard_data_server-0.7.0-py3-none-manylinux2014_x86_64.whl (6.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 91.8 MB/s eta 0:00:00
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.8/dist-packages (from pandas>=1.1.4->-r requirements.txt (line 26)) (2022.7.1)
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.4.1->-r requirements.txt (line 21)) (1.15.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.4.1->-r requirements.txt (line 21)) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.4.1->-r requirements.txt (line 21)) (0.2.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.4.1->-r requirements.txt (line 21)) (5.3.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.8/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.4.1->-r requirements.txt (line 21)) (1.3.1)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.8/dist-packages (from importlib-resources>=3.2.0->matplotlib>=3.2.2->-r requirements.txt (line 6)) (3.14.0)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.8/dist-packages (from markdown>=2.6.8->tensorboard>=2.4.1->-r requirements.txt (line 21)) (6.0.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.8/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.4.1->-r requirements.txt (line 21)) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.8/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.4.1->-r requirements.txt (line 21)) (3.2.2)
# Installing collected packages: tensorboard-data-server, smmap, setuptools, requests, psutil, Pillow, numpy, thop, scipy, pandas, opencv-python, gitdb, contourpy, matplotlib, gitpython, tensorboard, seaborn
#   Attempting uninstall: tensorboard-data-server
#     Found existing installation: tensorboard-data-server 0.6.1
#     Uninstalling tensorboard-data-server-0.6.1:
#       Successfully uninstalled tensorboard-data-server-0.6.1
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 57.4.0
#     Uninstalling setuptools-57.4.0:
#       Successfully uninstalled setuptools-57.4.0
#   Attempting uninstall: requests
#     Found existing installation: requests 2.25.1
#     Uninstalling requests-2.25.1:
#       Successfully uninstalled requests-2.25.1
#   Attempting uninstall: psutil
#     Found existing installation: psutil 5.4.8
#     Uninstalling psutil-5.4.8:
#       Successfully uninstalled psutil-5.4.8
#   Attempting uninstall: Pillow
#     Found existing installation: Pillow 7.1.2
#     Uninstalling Pillow-7.1.2:
#       Successfully uninstalled Pillow-7.1.2
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.22.4
#     Uninstalling numpy-1.22.4:
#       Successfully uninstalled numpy-1.22.4
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.7.3
#     Uninstalling scipy-1.7.3:
#       Successfully uninstalled scipy-1.7.3
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.3.5
#     Uninstalling pandas-1.3.5:
#       Successfully uninstalled pandas-1.3.5
#   Attempting uninstall: opencv-python
#     Found existing installation: opencv-python 4.6.0.66
#     Uninstalling opencv-python-4.6.0.66:
#       Successfully uninstalled opencv-python-4.6.0.66
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.5.3
#     Uninstalling matplotlib-3.5.3:
#       Successfully uninstalled matplotlib-3.5.3
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.11.2
#     Uninstalling tensorboard-2.11.2:
#       Successfully uninstalled tensorboard-2.11.2
#   Attempting uninstall: seaborn
#     Found existing installation: seaborn 0.11.2
#     Uninstalling seaborn-0.11.2:
#       Successfully uninstalled seaborn-0.11.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.9.0 requires jedi>=0.10, which is not installed.
# tensorflow 2.11.0 requires tensorboard<2.12,>=2.11, but you have tensorboard 2.12.0 which is incompatible.
# numba 0.56.4 requires numpy<1.24,>=1.18, but you have numpy 1.24.2 which is incompatible.
# cvxpy 1.2.3 requires setuptools<=64.0.2, but you have setuptools 67.4.0 which is incompatible.
# Successfully installed Pillow-9.4.0 contourpy-1.0.7 gitdb-4.0.10 gitpython-3.1.31 matplotlib-3.7.0 numpy-1.24.2 opencv-python-4.7.0.72 pandas-1.5.3 psutil-5.9.4 requests-2.28.2 scipy-1.10.1 seaborn-0.12.2 setuptools-67.4.0 smmap-5.0.0 tensorboard-2.12.0 tensorboard-data-server-0.7.0 thop-0.1.1.post2209072238

# %%
# !python detect.py --source https://www.youtube.com/watch?v=L3-XaUzaJHU&list=PLcKa-34z76PvI5KvI5S2JGj0RcBVuz3jg&index=172
# Out:
# detect: weights=yolov5s.pt, source=https://www.youtube.com/watch?v=L3-XaUzaJHU, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-114-g3c0a6e6 Python-3.8.10 torch-1.13.1+cu116 CPU
#
# Downloading https://github.com/ultralytics/yolov5/releases/download/v7.0/yolov5s.pt to yolov5s.pt...
# 100% 14.1M/14.1M [00:00<00:00, 130MB/s]
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients
# WARNING ⚠️ Environment does not support cv2.imshow() or PIL Image.show()
#
# requirements: YOLOv5 requirements "pafy" "youtube_dl==2020.12.2" not found, attempting AutoUpdate...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pafy
#   Downloading pafy-0.5.5-py2.py3-none-any.whl (35 kB)
# Collecting youtube_dl==2020.12.2
#   Downloading youtube_dl-2020.12.2-py2.py3-none-any.whl (1.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 28.7 MB/s eta 0:00:00
# Installing collected packages: youtube_dl, pafy
# Successfully installed pafy-0.5.5 youtube_dl-2020.12.2
#
# requirements: 2 packages updated per ('pafy', 'youtube_dl==2020.12.2')
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
# 1/1: https://www.youtube.com/watch?v=L3-XaUzaJHU...  Success (342 frames 1280x720 at 25.00 FPS)
#
# 0: 384x640 37 persons, 357.4ms
# 0: 384x640 34 persons, 290.4ms
# 0: 384x640 34 persons, 279.2ms
# 0: 384x640 34 persons, 264.1ms
# 0: 384x640 36 persons, 251.3ms
# 0: 384x640 37 persons, 269.8ms
# 0: 384x640 35 persons, 258.5ms
# 0: 384x640 35 persons, 251.0ms
# 0: 384x640 35 persons, 271.1ms
# 0: 384x640 36 persons, 252.4ms
# 0: 384x640 35 persons, 255.2ms
# 0: 384x640 37 persons, 256.7ms
# 0: 384x640 35 persons, 1 handbag, 257.9ms
# 0: 384x640 36 persons, 1 handbag, 252.8ms
# 0: 384x640 36 persons, 1 handbag, 254.5ms
# 0: 384x640 35 persons, 1 handbag, 260.8ms
# 0: 384x640 35 persons, 1 backpack, 1 handbag, 264.5ms
# 0: 384x640 35 persons, 1 backpack, 2 handbags, 259.1ms
# 0: 384x640 35 persons, 264.9ms
# 0: 384x640 36 persons, 256.3ms
# 0: 384x640 37 persons, 262.5ms
# 0: 384x640 35 persons, 284.9ms
# 0: 384x640 36 persons, 260.1ms
# 0: 384x640 37 persons, 265.6ms
# 0: 384x640 37 persons, 258.8ms
# 0: 384x640 37 persons, 267.0ms
# 0: 384x640 38 persons, 1 handbag, 259.2ms
# 0: 384x640 38 persons, 1 dog, 1 handbag, 261.5ms
# 0: 384x640 38 persons, 1 handbag, 289.5ms
# 0: 384x640 32 persons, 2 handbags, 408.4ms
# 0: 384x640 36 persons, 429.3ms
# 0: 384x640 39 persons, 427.4ms
# 0: 384x640 42 persons, 1 handbag, 417.6ms
# 0: 384x640 41 persons, 1 backpack, 1 handbag, 431.4ms
# 0: 384x640 39 persons, 1 dog, 1 handbag, 429.3ms
# 0: 384x640 37 persons, 1 dog, 1 handbag, 423.0ms
# 0: 384x640 39 persons, 1 handbag, 411.6ms
# 0: 384x640 38 persons, 1 handbag, 403.2ms
# 0: 384x640 36 persons, 1 dog, 415.5ms
# 0: 384x640 35 persons, 1 dog, 418.8ms
# 0: 384x640 35 persons, 1 handbag, 1 suitcase, 406.0ms
# 0: 384x640 33 persons, 2 handbags, 1 skis, 425.8ms
# 0: 384x640 33 persons, 1 handbag, 431.1ms
# 0: 384x640 34 persons, 1 handbag, 1 skis, 391.0ms
# 0: 384x640 34 persons, 1 handbag, 1 skis, 418.6ms
# 0: 384x640 36 persons, 364.3ms
# 0: 384x640 36 persons, 1 handbag, 256.6ms
# 0: 384x640 36 persons, 1 handbag, 268.2ms
# 0: 384x640 36 persons, 1 handbag, 257.0ms
# 0: 384x640 36 persons, 1 handbag, 251.1ms
# 0: 384x640 36 persons, 1 handbag, 249.8ms
# 0: 384x640 35 persons, 1 handbag, 253.1ms
# 0: 384x640 34 persons, 1 handbag, 266.5ms
# 0: 384x640 32 persons, 1 dog, 2 handbags, 248.1ms
# 0: 384x640 32 persons, 1 dog, 2 handbags, 257.4ms
# 0: 384x640 31 persons, 1 dog, 1 handbag, 267.3ms
# 0: 384x640 30 persons, 253.6ms
# 0: 384x640 30 persons, 263.2ms
# 0: 384x640 31 persons, 2 handbags, 261.1ms
# 0: 384x640 32 persons, 2 handbags, 1 skateboard, 271.4ms
# 0: 384x640 34 persons, 1 handbag, 266.4ms
# 0: 384x640 31 persons, 2 handbags, 259.2ms
# 0: 384x640 31 persons, 2 handbags, 270.9ms
# 0: 384x640 31 persons, 1 handbag, 265.6ms
# 0: 384x640 30 persons, 2 handbags, 262.4ms
# 0: 384x640 29 persons, 263.6ms
# 0: 384x640 29 persons, 2 handbags, 266.2ms
# 0: 384x640 29 persons, 2 handbags, 261.8ms
# 0: 384x640 29 persons, 249.6ms
# 0: 384x640 29 persons, 1 handbag, 302.6ms
# 0: 384x640 28 persons, 2 handbags, 259.1ms
# 0: 384x640 28 persons, 2 handbags, 248.7ms
# 0: 384x640 28 persons, 2 handbags, 257.1ms
# 0: 384x640 31 persons, 2 handbags, 284.0ms
# 0: 384x640 30 persons, 1 backpack, 4 handbags, 1 suitcase, 266.6ms
# 0: 384x640 31 persons, 1 backpack, 3 handbags, 261.2ms
# 0: 384x640 30 persons, 4 handbags, 1 suitcase, 282.8ms
# 0: 384x640 30 persons, 2 handbags, 1 suitcase, 262.8ms
# 0: 384x640 31 persons, 4 handbags, 258.1ms
# 0: 384x640 31 persons, 1 backpack, 3 handbags, 263.9ms
# 0: 384x640 31 persons, 2 handbags, 1 skis, 1 snowboard, 373.8ms
# 0: 384x640 29 persons, 1 backpack, 2 handbags, 420.4ms
# 0: 384x640 29 persons, 1 backpack, 2 handbags, 464.7ms
# 0: 384x640 34 persons, 1 backpack, 3 handbags, 446.9ms
# 0: 384x640 35 persons, 3 handbags, 446.0ms
# 0: 384x640 34 persons, 1 dog, 1 backpack, 4 handbags, 1 skis, 447.6ms
# 0: 384x640 34 persons, 2 backpacks, 1 handbag, 1 suitcase, 420.6ms
# 0: 384x640 33 persons, 3 handbags, 406.4ms
# 0: 384x640 33 persons, 2 handbags, 1 suitcase, 416.3ms
# 0: 384x640 35 persons, 1 backpack, 2 handbags, 432.7ms
# 0: 384x640 33 persons, 4 handbags, 1 skateboard, 395.1ms
# 0: 384x640 33 persons, 4 handbags, 1 skateboard, 435.2ms
# 0: 384x640 30 persons, 1 dog, 2 handbags, 395.4ms
# 0: 384x640 30 persons, 2 handbags, 421.3ms
# 0: 384x640 29 persons, 1 umbrella, 2 handbags, 416.0ms
# 0: 384x640 28 persons, 1 backpack, 1 umbrella, 2 handbags, 422.2ms
# 0: 384x640 27 persons, 2 handbags, 412.6ms
# 0: 384x640 28 persons, 2 handbags, 332.2ms
# 0: 384x640 28 persons, 2 handbags, 267.7ms
# 0: 384x640 28 persons, 2 handbags, 259.6ms
# 0: 384x640 28 persons, 2 handbags, 261.9ms
# 0: 384x640 28 persons, 2 handbags, 257.5ms
# 0: 384x640 28 persons, 2 handbags, 257.1ms
# 0: 384x640 28 persons, 2 handbags, 265.6ms
# 0: 384x640 30 persons, 1 backpack, 3 handbags, 271.9ms
# 0: 384x640 29 persons, 1 backpack, 3 handbags, 275.1ms
# 0: 384x640 29 persons, 3 handbags, 264.9ms
# 0: 384x640 29 persons, 3 handbags, 267.9ms
# 0: 384x640 31 persons, 1 dog, 2 handbags, 266.5ms
# 0: 384x640 31 persons, 3 handbags, 296.1ms
# 0: 384x640 33 persons, 1 handbag, 276.1ms
# 0: 384x640 32 persons, 1 handbag, 281.0ms
# 0: 384x640 29 persons, 3 handbags, 277.1ms
# 0: 384x640 33 persons, 2 handbags, 270.8ms
# 0: 384x640 29 persons, 1 dog, 1 handbag, 278.3ms
# 0: 384x640 30 persons, 1 dog, 3 handbags, 263.3ms
# 0: 384x640 30 persons, 1 dog, 3 handbags, 272.1ms
# 0: 384x640 29 persons, 4 handbags, 272.4ms
# 0: 384x640 31 persons, 3 handbags, 263.3ms
# 0: 384x640 31 persons, 1 handbag, 278.4ms
# 0: 384x640 33 persons, 1 handbag, 267.0ms
# 0: 384x640 31 persons, 1 handbag, 270.4ms
# 0: 384x640 31 persons, 268.6ms
# 0: 384x640 31 persons, 1 chair, 260.4ms
# 0: 384x640 31 persons, 270.9ms
# 0: 384x640 31 persons, 265.8ms
# 0: 384x640 32 persons, 266.8ms
# 0: 384x640 33 persons, 1 dog, 263.8ms
# 0: 384x640 32 persons, 265.6ms
# 0: 384x640 31 persons, 261.7ms
# 0: 384x640 31 persons, 281.0ms
# 0: 384x640 30 persons, 383.9ms
# 0: 384x640 29 persons, 1 handbag, 404.7ms
# 0: 384x640 29 persons, 1 handbag, 454.1ms
# 0: 384x640 30 persons, 442.2ms
# 0: 384x640 31 persons, 1 umbrella, 433.8ms
# 0: 384x640 33 persons, 1 umbrella, 415.7ms
# WARNING ⚠️ Video stream unresponsive, please check your IP camera connection.
# 0: 384x640 31 persons, 1 skis, 414.9ms
# 0: 384x640 (no detections), 395.9ms
# 0: 384x640 (no detections), 400.6ms
# 0: 384x640 (no detections), 416.2ms
# 0: 384x640 (no detections), 402.8ms
# 0: 384x640 (no detections), 395.6ms
# 0: 384x640 (no detections), 380.9ms
# 0: 384x640 (no detections), 394.2ms
# 0: 384x640 (no detections), 394.8ms
# 0: 384x640 (no detections), 406.3ms
# 0: 384x640 (no detections), 388.0ms
# Speed: 0.9ms pre-process, 317.9ms inference, 3.0ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
